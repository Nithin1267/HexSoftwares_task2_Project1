# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# -----------------------------
# Step 1: Load dataset
# -----------------------------
df = pd.read_csv("C:\\Users\\mrnit\\Downloads\\student_data.csv")

print("STUDENT DATASET")
print(df)
print("\nFirst 5 rows:")
print(df.head())

print("\nDataset Shape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

# -----------------------------
# Step 2: Split features and target
# -----------------------------
X = df.drop("Final_Result", axis=1)
y = df["Final_Result"]

# -----------------------------
# Step 3: Train-test split
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# -----------------------------
# Step 4: Train model
# -----------------------------
model = LogisticRegression()
model.fit(X_train, y_train)

# -----------------------------
# Step 5: Prediction
# -----------------------------
y_pred = model.predict(X_test)

# -----------------------------
# Step 6: Evaluation metrics
# -----------------------------
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("\nMODEL EVALUATION RESULTS")
print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)

# -----------------------------
# Step 7: Confusion matrix
# -----------------------------
cm = confusion_matrix(y_test, y_pred)

print("\nConfusion Matrix:")
print(cm)

# -----------------------------
# Step 8: Classification report
# -----------------------------
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# -----------------------------
# Step 9: Plot confusion matrix
# -----------------------------
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()

# -----------------------------
# Step 10: Bar chart of result distribution
# -----------------------------
df["Final_Result"].value_counts().plot(kind="bar")
plt.title("Pass and Fail Count")
plt.xlabel("Final Result")
plt.ylabel("Count")
plt.show()
# Out:
# STUDENT DATASET
#     Hours_Studied  Attendance  Assignments_Submitted  Previous_Score  \
# 0               2          60                      3              45
# 1               3          65                      4              50
# 2               4          70                      5              55
# 3               5          75                      6              60
# 4               6          80                      7              65
# 5               7          85                      8              70
# 6               1          50                      2              40
# 7               8          90                      9              85
# 8               2          55                      3              48
# 9               9          95                     10              90
# 10              4          68                      5              58
# 11              5          72                      6              62
# 12              6          78                      7              66
# 13              3          64                      4              52
# 14              7          88                      8              75
# 15              2          58                      3              46
# 16              8          92                      9              88
# 17              1          48                      2              38
# 18              5          76                      6              61
# 19              6          82                      7              69
#
#     Final_Result
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1
# 5              1
# 6              0
# 7              1
# 8              0
# 9              1
# 10             0
# 11             1
# 12             1
# 13             0
# 14             1
# 15             0
# 16             1
# 17             0
# 18             1
# 19             1
#
# First 5 rows:
#    Hours_Studied  Attendance  Assignments_Submitted  Previous_Score  \
# 0              2          60                      3              45
# 1              3          65                      4              50
# 2              4          70                      5              55
# 3              5          75                      6              60
# 4              6          80                      7              65
#
#    Final_Result
# 0             0
# 1             0
# 2             0
# 3             1
# 4             1
#
# Dataset Shape:
# (20, 5)
#
# Column Names:
# ['Hours_Studied', 'Attendance', 'Assignments_Submitted', 'Previous_Score', 'Final_Result']
#
# MODEL EVALUATION RESULTS
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
#
# Confusion Matrix:
# [[5 0]
#  [0 1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
